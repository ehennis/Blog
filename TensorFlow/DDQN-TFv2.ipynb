# %% [markdown]
# # Double Deep Q-Network with TensorFlow v2 and Keras

# %% [markdown]
# In 2016, Google DeepMind ([Link](https://www.aaai.org/ocs/index.php/AAAI/AAAI16/paper/download/12389/11847)) decided to alter the DQN algorithm the same way the original Q-Learner algorithm was updated by adding a second network. The team found that the overestimation that affected the q-learner also affected the DQN algoritm. When the original double q-learner was introduced they proved that it worked in that setting and in this paper they prove it can be generalized to work with large scale function approximation.

# %% [markdown]
# **Summary**
# This algorithm combines the benefits of the Double Q-Learner as the benefits of deep learning. We get the function approximation so that we can have a continuous state space plus we keep from having the overestimation from Q-Learning. This document will be a combination of the DQN and Double Q-Learner so it will be mostly review. But, this algorithm is so much more powerful that you should explore the other gyms at OpenAI and see what you can solve.
#
# One thing to note, we need to update the weights of the second neural network with the weights from the first neural network. We didn't do this in the Double Q-Learner since the tables were both getting updated.

# %% [markdown]
# **CartPole Example**
# Again we will use the [CartPole](https://gym.openai.com/envs/CartPole-v1/) environment from OpenAI.
#
# The actions are 0 to push the cart to the left and 1 to push the cart to the right.
#
# The continuous state space is an X coordinate for location, the velocity of the cart, the angle of the pole, and the velocity at the tip of the pole. The X coordinate goes from -4.8 to +4.8, velocity is -Inf to +Inf, angle of the pole goes from -24 degrees to +24 degrees, tip velocity is -Inf to +Inf. With all of the possible combinations you can see why we can't create a Q table for each one.
#
# To "solve" this puzzle you have to have an average reward of > 195 over 100 consecutive episodes. One thing to note, I am hard capping the rewards at 210 so this number can't average above that and it also could potentially drive the average down.

# %% [markdown]
# **OpenAI Install**
# While I already have all of the [OpenAI](https://openai.com/) stuff installed in my main environment I need to do the same thing here. Here are the commands that I had to run:
# git clone https://github.com/openai/gym
# cd gym
# pip install -e .
# pip install gym
# pip install gym[all]
#
# There will be some failures since I am running on Windows but it will install enough for me to run the CartPole gym.

# %% [markdown]
# ## TensorFlow v2 Changes

# %% [markdown]
# This notebook is a pretty close duplicate to my RL notebook I created. For the most part, I am using Keras for the heavy lifting so there are not many changes that need to be done.
#
# Since this WAS a new environment I had to install all of the OpenAI gym related libraries.
#
# * I added the import for TensorFlow and Keras
# * With those changes I also had to add *keras.layers.* to Sequential and Dense while creating the model

# %%
#Imports and gym creation
import gym
import numpy as np
import matplotlib.pyplot as plt
from collections import deque
import random

#TensorFlow Libraries
import tensorflow as tf 
from tensorflow import keras

#Create Gym
from gym import wrappers
envCartPole = gym.make('CartPole-v1')
envCartPole.seed(50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-3ae4602cd333> in <module>
#      10 from tensorflow import keras
#      11 #from keras.models import Sequential
# ---> 12 from keras.layers import Sequential, Dense
#      13 #from keras.optimizers import Adam
#      14
#
# ModuleNotFoundError: No module named 'keras'

# %%
#Hyper Parameters
EPISODES = 500
TRAIN_END = 0

def discount_rate(): #Gamma
    return 0.95

def learning_rate(): #Alpha
    return 0.001

def batch_size():
    return 24

# %% [markdown]
# **Double Deep Q-Network Class**
# This class is the same as the DQN class from the last notebook with a few exceptions.
# **init**:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;We create a second NN for the target network
#
# **update_target_from_model(self)**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;This class updates the weights of the target NN from the model NN
#
# **build_model(self)**:
# **action(self,state)**:
# **test_action(self,state)**:
# **store(self, state, action, reward, nstate, done)**:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Same
#
# **experience_replay(self, batch_size)**:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;This class has the Double DQN changes. We grab the prediction targets from the target NN and then use that in the Q update rule.

# %%
class DoubleDeepQNetwork():
    def __init__(self, states, actions, alpha, gamma, epsilon,epsilon_min, epsilon_decay):
        self.nS = states
        self.nA = actions
        self.memory = deque([], maxlen=2500)
        self.alpha = alpha
        self.gamma = gamma
        #Explore/Exploit
        self.epsilon = epsilon
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.model = self.build_model()
        self.model_target = self.build_model() #Second (target) neural network
        self.update_target_from_model() #Update weights
        self.loss = []
        
    def build_model(self):
        model = keras.Sequential() #linear stack of layers https://keras.io/models/sequential/
        model.add(keras.layers.Dense(24, input_dim=self.nS, activation='relu')) #[Input] -> Layer 1
        #   Dense: Densely connected layer https://keras.io/layers/core/
        #   24: Number of neurons
        #   input_dim: Number of input variables
        #   activation: Rectified Linear Unit (relu) ranges >= 0
        model.add(keras.layers.Dense(24, activation='relu')) #Layer 2 -> 3
        model.add(keras.layers.Dense(self.nA, activation='linear')) #Layer 3 -> [output]
        #   Size has to match the output (different actions)
        #   Linear activation on the last layer
        model.compile(loss='mean_squared_error', #Loss function: Mean Squared Error
                      optimizer=keras.optimizers.Adam(lr=self.alpha)) #Optimaizer: Adam (Feel free to check other options)
        return model

    def update_target_from_model(self):
        #Update the target model from the base model
        self.model_target.set_weights( self.model.get_weights() )

    def action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.nA) #Explore
        action_vals = self.model.predict(state) #Exploit: Use the NN to predict the correct action from this state
        return np.argmax(action_vals[0])

    def test_action(self, state): #Exploit
        action_vals = self.model.predict(state)
        return np.argmax(action_vals[0])

    def store(self, state, action, reward, nstate, done):
        #Store the experience in memory
        self.memory.append( (state, action, reward, nstate, done) )

    def experience_replay(self, batch_size):
        #Execute the experience replay
        minibatch = random.sample( self.memory, batch_size ) #Randomly sample from memory

        #Convert to numpy for speed by vectorization
        x = []
        y = []
        np_array = np.array(minibatch)
        st = np.zeros((0,self.nS)) #States
        nst = np.zeros( (0,self.nS) )#Next States
        for i in range(len(np_array)): #Creating the state and next state np arrays
            st = np.append( st, np_array[i,0], axis=0)
            nst = np.append( nst, np_array[i,3], axis=0)
        st_predict = self.model.predict(st) #Here is the speedup! I can predict on the ENTIRE batch
        nst_predict = self.model.predict(nst)
        nst_predict_target = self.model_target.predict(nst) #Predict from the TARGET
        index = 0
        for state, action, reward, nstate, done in minibatch:
            x.append(state)
            #Predict from state
            nst_action_predict_target = nst_predict_target[index]
            nst_action_predict_model = nst_predict[index]
            if done == True: #Terminal: Just assign reward much like {* (not done) - QB[state][action]}
                target = reward
            else:   #Non terminal
                target = reward + self.gamma * nst_action_predict_target[np.argmax(nst_action_predict_model)] #Using Q to get T is Double DQN
            target_f = st_predict[index]
            target_f[action] = target
            y.append(target_f)
            index += 1
        #Reshape for Keras Fit
        x_reshape = np.array(x).reshape(batch_size,self.nS)
        y_reshape = np.array(y)
        epoch_count = 1
        hist = self.model.fit(x_reshape, y_reshape, epochs=epoch_count, verbose=0)
        #Graph Losses
        for i in range(epoch_count):
            self.loss.append( hist.history['loss'][i] )
        #Decay Epsilon
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
#Create the agents
nS = envCartPole.observation_space.shape[0] #This is only 4
nA = envCartPole.action_space.n #Actions
dqn = DoubleDeepQNetwork(nS, nA, learning_rate(), discount_rate(), 1, 0.001, 0.995 )

batch_size = batch_size()
# Out:
# [2019-01-22 08:34:28,472] From C:\Users\nurl_\Anaconda3\envs\tf_daily\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:662: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#Training
rewards = [] #Store rewards for graphing
epsilons = [] # Store the Explore/Exploit
TEST_Episodes = 0
for e in range(EPISODES):
    state = envCartPole.reset()
    state = np.reshape(state, [1, nS]) # Resize to store in memory to pass to .predict
    tot_rewards = 0
    for time in range(210): #200 is when you "solve" the game. This can continue forever as far as I know
        action = dqn.action(state)
        nstate, reward, done, _ = envCartPole.step(action)
        nstate = np.reshape(nstate, [1, nS])
        tot_rewards += reward
        dqn.store(state, action, reward, nstate, done) # Resize to store in memory to pass to .predict
        state = nstate
        #done: CartPole fell. 
        #time == 209: CartPole stayed upright
        if done or time == 209:
            rewards.append(tot_rewards)
            epsilons.append(dqn.epsilon)
            print("episode: {}/{}, score: {}, e: {}"
                  .format(e, EPISODES, tot_rewards, dqn.epsilon))
            break
        #Experience Replay
        if len(dqn.memory) > batch_size:
            dqn.experience_replay(batch_size)
    #Update the weights after each episode (You can configure this for x steps as well
    dqn.update_target_from_model()
    #If our current NN passes we are done
    #I am going to use the last 5 runs
    if len(rewards) > 5 and np.average(rewards[-5:]) > 195:
        #Set the rest of the EPISODES for testing
        TEST_Episodes = EPISODES - e
        TRAIN_END = e
        break
# Out:
# [2019-01-22 08:34:42,714] From C:\Users\nurl_\Anaconda3\envs\tf_daily\lib\site-packages\tensorflow\python\ops\math_ops.py:3068: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# episode: 0/500, score: 29.0, e: 0.9801495006250001
# episode: 1/500, score: 19.0, e: 0.8955869907338783
# episode: 2/500, score: 15.0, e: 0.8348931673187264
# episode: 3/500, score: 25.0, e: 0.7402609576967045
# episode: 4/500, score: 25.0, e: 0.6563549768288433
# episode: 5/500, score: 14.0, e: 0.6149486215357263
# episode: 6/500, score: 10.0, e: 0.5878229785513479
# episode: 7/500, score: 13.0, e: 0.5535075230322891
# episode: 8/500, score: 13.0, e: 0.5211953074858876
# episode: 9/500, score: 11.0, e: 0.49571413690105054
# episode: 10/500, score: 23.0, e: 0.4439551321314536
# episode: 11/500, score: 11.0, e: 0.4222502236424958
# episode: 12/500, score: 10.0, e: 0.4036245882390106
# episode: 13/500, score: 11.0, e: 0.38389143477919885
# episode: 14/500, score: 8.0, e: 0.3706551064126331
# episode: 15/500, score: 13.0, e: 0.34901730169741024
# episode: 16/500, score: 20.0, e: 0.3173112652388396
# episode: 17/500, score: 11.0, e: 0.3017979588795719
# episode: 18/500, score: 10.0, e: 0.2884855236625661
# episode: 19/500, score: 11.0, e: 0.2743815040481898
# episode: 20/500, score: 10.0, e: 0.26227842021373715
# episode: 21/500, score: 11.0, e: 0.2494556624678441
# episode: 22/500, score: 10.0, e: 0.2384520680152932
# episode: 23/500, score: 13.0, e: 0.22453190559909803
# episode: 24/500, score: 11.0, e: 0.21355457002808648
# episode: 25/500, score: 9.0, e: 0.20516038984972615
# episode: 26/500, score: 26.0, e: 0.18099664897669618
# episode: 27/500, score: 14.0, e: 0.16957841978827493
# episode: 28/500, score: 16.0, e: 0.1572956799768517
# episode: 29/500, score: 15.0, e: 0.14663577052834775
# episode: 30/500, score: 20.0, e: 0.13331482894782642
# episode: 31/500, score: 10.0, e: 0.12743425563174798
# episode: 32/500, score: 9.0, e: 0.12242520289863423
# episode: 33/500, score: 9.0, e: 0.1176130407830293
# episode: 34/500, score: 11.0, e: 0.11186295456362313
# episode: 35/500, score: 11.0, e: 0.1063939893092943
# episode: 36/500, score: 8.0, e: 0.10272559337455119
# episode: 37/500, score: 10.0, e: 0.09819432413732986
# episode: 38/500, score: 10.0, e: 0.09386293109673778
# episode: 39/500, score: 21.0, e: 0.08490939117940327
# episode: 40/500, score: 25.0, e: 0.07528520976374668
# episode: 41/500, score: 61.0, e: 0.05573070148010834
# episode: 42/500, score: 20.0, e: 0.05066791621302729
# episode: 43/500, score: 27.0, e: 0.04447676004441063
# episode: 44/500, score: 33.0, e: 0.0378853869148274
# episode: 45/500, score: 16.0, e: 0.03514130927386981
# episode: 46/500, score: 16.0, e: 0.032595988006089364
# episode: 47/500, score: 16.0, e: 0.030235026982422884
# episode: 48/500, score: 26.0, e: 0.026673952849996664
# episode: 49/500, score: 21.0, e: 0.024129537298457977
# episode: 50/500, score: 25.0, e: 0.021394538952450012
# episode: 51/500, score: 36.0, e: 0.017951913959130504
# episode: 52/500, score: 50.0, e: 0.014042412118399107
# episode: 53/500, score: 15.0, e: 0.013090759526015528
# episode: 54/500, score: 19.0, e: 0.011961352755726806
# episode: 55/500, score: 39.0, e: 0.009886836832061067
# episode: 56/500, score: 39.0, e: 0.008172114353621017
# episode: 57/500, score: 43.0, e: 0.0066206987359377885
# episode: 58/500, score: 22.0, e: 0.005959207695953885
# episode: 59/500, score: 25.0, e: 0.005283752423423922
# episode: 60/500, score: 67.0, e: 0.0037954719768877486
# episode: 61/500, score: 35.0, e: 0.0032007410118464487
# episode: 62/500, score: 19.0, e: 0.002924596716205228
# episode: 63/500, score: 38.0, e: 0.0024295171864449163
# episode: 64/500, score: 49.0, e: 0.0019099757418491003
# episode: 65/500, score: 39.0, e: 0.001578719305290601
# episode: 66/500, score: 29.0, e: 0.0013719907413879291
# episode: 67/500, score: 76.0, e: 0.0009954703940636294
# episode: 68/500, score: 84.0, e: 0.0009954703940636294
# episode: 69/500, score: 48.0, e: 0.0009954703940636294
# episode: 70/500, score: 56.0, e: 0.0009954703940636294
# episode: 71/500, score: 44.0, e: 0.0009954703940636294
# episode: 72/500, score: 60.0, e: 0.0009954703940636294
# episode: 73/500, score: 44.0, e: 0.0009954703940636294
# episode: 74/500, score: 83.0, e: 0.0009954703940636294
# episode: 75/500, score: 35.0, e: 0.0009954703940636294
# episode: 76/500, score: 44.0, e: 0.0009954703940636294
# episode: 77/500, score: 56.0, e: 0.0009954703940636294
# episode: 78/500, score: 52.0, e: 0.0009954703940636294
# episode: 79/500, score: 82.0, e: 0.0009954703940636294
# episode: 80/500, score: 118.0, e: 0.0009954703940636294
# episode: 81/500, score: 47.0, e: 0.0009954703940636294
# episode: 82/500, score: 51.0, e: 0.0009954703940636294
# episode: 83/500, score: 70.0, e: 0.0009954703940636294
# episode: 84/500, score: 30.0, e: 0.0009954703940636294
# episode: 85/500, score: 58.0, e: 0.0009954703940636294
# episode: 86/500, score: 57.0, e: 0.0009954703940636294
# episode: 87/500, score: 56.0, e: 0.0009954703940636294
# episode: 88/500, score: 109.0, e: 0.0009954703940636294
# episode: 89/500, score: 37.0, e: 0.0009954703940636294
# episode: 90/500, score: 81.0, e: 0.0009954703940636294
# episode: 91/500, score: 83.0, e: 0.0009954703940636294
# episode: 92/500, score: 102.0, e: 0.0009954703940636294
# episode: 93/500, score: 74.0, e: 0.0009954703940636294
# episode: 94/500, score: 88.0, e: 0.0009954703940636294
# episode: 95/500, score: 210.0, e: 0.0009954703940636294
# episode: 96/500, score: 108.0, e: 0.0009954703940636294
# episode: 97/500, score: 89.0, e: 0.0009954703940636294
# episode: 98/500, score: 98.0, e: 0.0009954703940636294
# episode: 99/500, score: 126.0, e: 0.0009954703940636294
# episode: 100/500, score: 117.0, e: 0.0009954703940636294
# episode: 101/500, score: 123.0, e: 0.0009954703940636294
# episode: 102/500, score: 126.0, e: 0.0009954703940636294
# episode: 103/500, score: 145.0, e: 0.0009954703940636294
# episode: 104/500, score: 180.0, e: 0.0009954703940636294
# episode: 105/500, score: 160.0, e: 0.0009954703940636294
# episode: 106/500, score: 187.0, e: 0.0009954703940636294
# episode: 107/500, score: 210.0, e: 0.0009954703940636294
# episode: 108/500, score: 210.0, e: 0.0009954703940636294
# episode: 109/500, score: 210.0, e: 0.0009954703940636294

# %%
#Testing
print('Training complete. Testing started...')
#TEST Time
#   In this section we ALWAYS use exploit don't train any more
for e_test in range(TEST_Episodes):
    state = envCartPole.reset()
    state = np.reshape(state, [1, nS])
    tot_rewards = 0
    for t_test in range(210):
        action = dqn.test_action(state)
        nstate, reward, done, _ = envCartPole.step(action)
        nstate = np.reshape( nstate, [1, nS])
        tot_rewards += reward
        #DON'T STORE ANYTHING DURING TESTING
        state = nstate
        #done: CartPole fell. 
        #t_test == 209: CartPole stayed upright
        if done or t_test == 209: 
            rewards.append(tot_rewards)
            epsilons.append(0) #We are doing full exploit
            print("episode: {}/{}, score: {}, e: {}"
                  .format(e_test, TEST_Episodes, tot_rewards, 0))
            break;
# Out:
# Training complete. Testing started...
# episode: 0/391, score: 210.0, e: 0
# episode: 1/391, score: 210.0, e: 0
# episode: 2/391, score: 210.0, e: 0
# episode: 3/391, score: 210.0, e: 0
# episode: 4/391, score: 157.0, e: 0
# episode: 5/391, score: 118.0, e: 0
# episode: 6/391, score: 210.0, e: 0
# episode: 7/391, score: 210.0, e: 0
# episode: 8/391, score: 172.0, e: 0
# episode: 9/391, score: 210.0, e: 0
# episode: 10/391, score: 130.0, e: 0
# episode: 11/391, score: 210.0, e: 0
# episode: 12/391, score: 190.0, e: 0
# episode: 13/391, score: 210.0, e: 0
# episode: 14/391, score: 210.0, e: 0
# episode: 15/391, score: 210.0, e: 0
# episode: 16/391, score: 210.0, e: 0
# episode: 17/391, score: 210.0, e: 0
# episode: 18/391, score: 210.0, e: 0
# episode: 19/391, score: 210.0, e: 0
# episode: 20/391, score: 210.0, e: 0
# episode: 21/391, score: 124.0, e: 0
# episode: 22/391, score: 210.0, e: 0
# episode: 23/391, score: 210.0, e: 0
# episode: 24/391, score: 210.0, e: 0
# episode: 25/391, score: 210.0, e: 0
# episode: 26/391, score: 210.0, e: 0
# episode: 27/391, score: 210.0, e: 0
# episode: 28/391, score: 184.0, e: 0
# episode: 29/391, score: 210.0, e: 0
# episode: 30/391, score: 210.0, e: 0
# episode: 31/391, score: 210.0, e: 0
# episode: 32/391, score: 210.0, e: 0
# episode: 33/391, score: 210.0, e: 0
# episode: 34/391, score: 210.0, e: 0
# episode: 35/391, score: 210.0, e: 0
# episode: 36/391, score: 124.0, e: 0
# episode: 37/391, score: 210.0, e: 0
# episode: 38/391, score: 210.0, e: 0
# episode: 39/391, score: 210.0, e: 0
# episode: 40/391, score: 209.0, e: 0
# episode: 41/391, score: 210.0, e: 0
# episode: 42/391, score: 210.0, e: 0
# episode: 43/391, score: 210.0, e: 0
# episode: 44/391, score: 120.0, e: 0
# episode: 45/391, score: 210.0, e: 0
# episode: 46/391, score: 187.0, e: 0
# episode: 47/391, score: 128.0, e: 0
# episode: 48/391, score: 210.0, e: 0
# episode: 49/391, score: 210.0, e: 0
# episode: 50/391, score: 210.0, e: 0
# episode: 51/391, score: 208.0, e: 0
# episode: 52/391, score: 210.0, e: 0
# episode: 53/391, score: 210.0, e: 0
# episode: 54/391, score: 133.0, e: 0
# episode: 55/391, score: 210.0, e: 0
# episode: 56/391, score: 210.0, e: 0
# episode: 57/391, score: 210.0, e: 0
# episode: 58/391, score: 210.0, e: 0
# episode: 59/391, score: 210.0, e: 0
# episode: 60/391, score: 210.0, e: 0
# episode: 61/391, score: 210.0, e: 0
# episode: 62/391, score: 210.0, e: 0
# episode: 63/391, score: 210.0, e: 0
# episode: 64/391, score: 210.0, e: 0
# episode: 65/391, score: 210.0, e: 0
# episode: 66/391, score: 210.0, e: 0
# episode: 67/391, score: 210.0, e: 0
# episode: 68/391, score: 210.0, e: 0
# episode: 69/391, score: 210.0, e: 0
# episode: 70/391, score: 134.0, e: 0
# episode: 71/391, score: 210.0, e: 0
# episode: 72/391, score: 210.0, e: 0
# episode: 73/391, score: 178.0, e: 0
# episode: 74/391, score: 140.0, e: 0
# episode: 75/391, score: 210.0, e: 0
# episode: 76/391, score: 210.0, e: 0
# episode: 77/391, score: 210.0, e: 0
# episode: 78/391, score: 210.0, e: 0
# episode: 79/391, score: 104.0, e: 0
# episode: 80/391, score: 210.0, e: 0
# episode: 81/391, score: 210.0, e: 0
# episode: 82/391, score: 210.0, e: 0
# episode: 83/391, score: 196.0, e: 0
# episode: 84/391, score: 210.0, e: 0
# episode: 85/391, score: 210.0, e: 0
# episode: 86/391, score: 210.0, e: 0
# episode: 87/391, score: 210.0, e: 0
# episode: 88/391, score: 210.0, e: 0
# episode: 89/391, score: 184.0, e: 0
# episode: 90/391, score: 204.0, e: 0
# episode: 91/391, score: 210.0, e: 0
# episode: 92/391, score: 210.0, e: 0
# episode: 93/391, score: 152.0, e: 0
# episode: 94/391, score: 104.0, e: 0
# episode: 95/391, score: 210.0, e: 0
# episode: 96/391, score: 190.0, e: 0
# episode: 97/391, score: 210.0, e: 0
# episode: 98/391, score: 190.0, e: 0
# episode: 99/391, score: 125.0, e: 0
# episode: 100/391, score: 210.0, e: 0
# episode: 101/391, score: 142.0, e: 0
# episode: 102/391, score: 210.0, e: 0
# episode: 103/391, score: 210.0, e: 0
# episode: 104/391, score: 210.0, e: 0
# episode: 105/391, score: 152.0, e: 0
# episode: 106/391, score: 188.0, e: 0
# episode: 107/391, score: 201.0, e: 0
# episode: 108/391, score: 210.0, e: 0
# episode: 109/391, score: 210.0, e: 0
# episode: 110/391, score: 183.0, e: 0
# episode: 111/391, score: 210.0, e: 0
# episode: 112/391, score: 210.0, e: 0
# episode: 113/391, score: 210.0, e: 0
# episode: 114/391, score: 210.0, e: 0
# episode: 115/391, score: 210.0, e: 0
# episode: 116/391, score: 210.0, e: 0
# episode: 117/391, score: 210.0, e: 0
# episode: 118/391, score: 210.0, e: 0
# episode: 119/391, score: 210.0, e: 0
# episode: 120/391, score: 125.0, e: 0
# episode: 121/391, score: 207.0, e: 0
# episode: 122/391, score: 210.0, e: 0
# episode: 123/391, score: 210.0, e: 0
# episode: 124/391, score: 210.0, e: 0
# episode: 125/391, score: 174.0, e: 0
# episode: 126/391, score: 113.0, e: 0
# episode: 127/391, score: 210.0, e: 0
# episode: 128/391, score: 210.0, e: 0
# episode: 129/391, score: 123.0, e: 0
# episode: 130/391, score: 210.0, e: 0
# episode: 131/391, score: 210.0, e: 0
# episode: 132/391, score: 210.0, e: 0
# episode: 133/391, score: 210.0, e: 0
# episode: 134/391, score: 210.0, e: 0
# episode: 135/391, score: 210.0, e: 0
# episode: 136/391, score: 210.0, e: 0
# episode: 137/391, score: 210.0, e: 0
# episode: 138/391, score: 210.0, e: 0
# episode: 139/391, score: 210.0, e: 0
# episode: 140/391, score: 210.0, e: 0
# episode: 141/391, score: 210.0, e: 0
# episode: 142/391, score: 210.0, e: 0
# episode: 143/391, score: 210.0, e: 0
# episode: 144/391, score: 132.0, e: 0
# episode: 145/391, score: 210.0, e: 0
# episode: 146/391, score: 205.0, e: 0
# episode: 147/391, score: 210.0, e: 0
# episode: 148/391, score: 210.0, e: 0
# episode: 149/391, score: 210.0, e: 0
# episode: 150/391, score: 125.0, e: 0
# episode: 151/391, score: 210.0, e: 0
# episode: 152/391, score: 210.0, e: 0
# episode: 153/391, score: 210.0, e: 0
# episode: 154/391, score: 210.0, e: 0
# episode: 155/391, score: 210.0, e: 0
# episode: 156/391, score: 210.0, e: 0
# episode: 157/391, score: 189.0, e: 0
# episode: 158/391, score: 210.0, e: 0
# episode: 159/391, score: 210.0, e: 0
# episode: 160/391, score: 183.0, e: 0
# episode: 161/391, score: 210.0, e: 0
# episode: 162/391, score: 210.0, e: 0
# episode: 163/391, score: 210.0, e: 0
# episode: 164/391, score: 210.0, e: 0
# episode: 165/391, score: 210.0, e: 0
# episode: 166/391, score: 210.0, e: 0
# episode: 167/391, score: 210.0, e: 0
# episode: 168/391, score: 210.0, e: 0
# episode: 169/391, score: 210.0, e: 0
# episode: 170/391, score: 195.0, e: 0
# episode: 171/391, score: 201.0, e: 0
# episode: 172/391, score: 210.0, e: 0
# episode: 173/391, score: 157.0, e: 0
# episode: 174/391, score: 210.0, e: 0
# episode: 175/391, score: 210.0, e: 0
# episode: 176/391, score: 210.0, e: 0
# episode: 177/391, score: 191.0, e: 0
# episode: 178/391, score: 210.0, e: 0
# episode: 179/391, score: 210.0, e: 0
# episode: 180/391, score: 210.0, e: 0
# episode: 181/391, score: 210.0, e: 0
# episode: 182/391, score: 210.0, e: 0
# episode: 183/391, score: 146.0, e: 0
# episode: 184/391, score: 210.0, e: 0
# episode: 185/391, score: 210.0, e: 0
# episode: 186/391, score: 184.0, e: 0
# episode: 187/391, score: 210.0, e: 0
# episode: 188/391, score: 210.0, e: 0
# episode: 189/391, score: 210.0, e: 0
# episode: 190/391, score: 210.0, e: 0
# episode: 191/391, score: 210.0, e: 0
# episode: 192/391, score: 210.0, e: 0
# episode: 193/391, score: 210.0, e: 0
# episode: 194/391, score: 177.0, e: 0
# episode: 195/391, score: 210.0, e: 0
# episode: 196/391, score: 210.0, e: 0
# episode: 197/391, score: 210.0, e: 0
# episode: 198/391, score: 134.0, e: 0
# episode: 199/391, score: 103.0, e: 0
# episode: 200/391, score: 210.0, e: 0
# episode: 201/391, score: 210.0, e: 0
# episode: 202/391, score: 210.0, e: 0
# episode: 203/391, score: 210.0, e: 0
# episode: 204/391, score: 210.0, e: 0
# episode: 205/391, score: 210.0, e: 0
# episode: 206/391, score: 210.0, e: 0
# episode: 207/391, score: 141.0, e: 0
# episode: 208/391, score: 210.0, e: 0
# episode: 209/391, score: 210.0, e: 0
# episode: 210/391, score: 210.0, e: 0
# episode: 211/391, score: 148.0, e: 0
# episode: 212/391, score: 210.0, e: 0
# episode: 213/391, score: 210.0, e: 0
# episode: 214/391, score: 126.0, e: 0
# episode: 215/391, score: 210.0, e: 0
# episode: 216/391, score: 202.0, e: 0
# episode: 217/391, score: 210.0, e: 0
# episode: 218/391, score: 210.0, e: 0
# episode: 219/391, score: 204.0, e: 0
# episode: 220/391, score: 210.0, e: 0
# episode: 221/391, score: 210.0, e: 0
# episode: 222/391, score: 210.0, e: 0
# episode: 223/391, score: 210.0, e: 0
# episode: 224/391, score: 210.0, e: 0
# episode: 225/391, score: 204.0, e: 0
# episode: 226/391, score: 193.0, e: 0
# episode: 227/391, score: 210.0, e: 0
# episode: 228/391, score: 210.0, e: 0
# episode: 229/391, score: 98.0, e: 0
# episode: 230/391, score: 210.0, e: 0
# episode: 231/391, score: 134.0, e: 0
# episode: 232/391, score: 210.0, e: 0
# episode: 233/391, score: 210.0, e: 0
# episode: 234/391, score: 210.0, e: 0
# episode: 235/391, score: 210.0, e: 0
# episode: 236/391, score: 139.0, e: 0
# episode: 237/391, score: 210.0, e: 0
# episode: 238/391, score: 210.0, e: 0
# episode: 239/391, score: 114.0, e: 0
# episode: 240/391, score: 210.0, e: 0
# episode: 241/391, score: 210.0, e: 0
# episode: 242/391, score: 210.0, e: 0
# episode: 243/391, score: 210.0, e: 0
# episode: 244/391, score: 210.0, e: 0
# episode: 245/391, score: 210.0, e: 0
# episode: 246/391, score: 201.0, e: 0
# episode: 247/391, score: 210.0, e: 0
# episode: 248/391, score: 210.0, e: 0
# episode: 249/391, score: 210.0, e: 0
# episode: 250/391, score: 210.0, e: 0
# episode: 251/391, score: 210.0, e: 0
# episode: 252/391, score: 210.0, e: 0
# episode: 253/391, score: 210.0, e: 0
# episode: 254/391, score: 210.0, e: 0
# episode: 255/391, score: 210.0, e: 0
# episode: 256/391, score: 210.0, e: 0
# episode: 257/391, score: 210.0, e: 0
# episode: 258/391, score: 210.0, e: 0
# episode: 259/391, score: 130.0, e: 0
# episode: 260/391, score: 210.0, e: 0
# episode: 261/391, score: 210.0, e: 0
# episode: 262/391, score: 210.0, e: 0
# episode: 263/391, score: 210.0, e: 0
# episode: 264/391, score: 210.0, e: 0
# episode: 265/391, score: 127.0, e: 0
# episode: 266/391, score: 207.0, e: 0
# episode: 267/391, score: 210.0, e: 0
# episode: 268/391, score: 210.0, e: 0
# episode: 269/391, score: 210.0, e: 0
# episode: 270/391, score: 210.0, e: 0
# episode: 271/391, score: 207.0, e: 0
# episode: 272/391, score: 114.0, e: 0
# episode: 273/391, score: 108.0, e: 0
# episode: 274/391, score: 203.0, e: 0
# episode: 275/391, score: 210.0, e: 0
# episode: 276/391, score: 210.0, e: 0
# episode: 277/391, score: 130.0, e: 0
# episode: 278/391, score: 210.0, e: 0
# episode: 279/391, score: 202.0, e: 0
# episode: 280/391, score: 210.0, e: 0
# episode: 281/391, score: 210.0, e: 0
# episode: 282/391, score: 210.0, e: 0
# episode: 283/391, score: 210.0, e: 0
# episode: 284/391, score: 210.0, e: 0
# episode: 285/391, score: 210.0, e: 0
# episode: 286/391, score: 210.0, e: 0
# episode: 287/391, score: 210.0, e: 0
# episode: 288/391, score: 113.0, e: 0
# episode: 289/391, score: 210.0, e: 0
# episode: 290/391, score: 210.0, e: 0
# episode: 291/391, score: 210.0, e: 0
# episode: 292/391, score: 210.0, e: 0
# episode: 293/391, score: 128.0, e: 0
# episode: 294/391, score: 210.0, e: 0
# episode: 295/391, score: 184.0, e: 0
# episode: 296/391, score: 210.0, e: 0
# episode: 297/391, score: 210.0, e: 0
# episode: 298/391, score: 210.0, e: 0
# episode: 299/391, score: 210.0, e: 0
# episode: 300/391, score: 210.0, e: 0
# episode: 301/391, score: 210.0, e: 0
# episode: 302/391, score: 138.0, e: 0
# episode: 303/391, score: 210.0, e: 0
# episode: 304/391, score: 210.0, e: 0
# episode: 305/391, score: 114.0, e: 0
# episode: 306/391, score: 210.0, e: 0
# episode: 307/391, score: 210.0, e: 0
# episode: 308/391, score: 210.0, e: 0
# episode: 309/391, score: 210.0, e: 0
# episode: 310/391, score: 210.0, e: 0
# episode: 311/391, score: 210.0, e: 0
# episode: 312/391, score: 210.0, e: 0
# episode: 313/391, score: 210.0, e: 0
# episode: 314/391, score: 210.0, e: 0
# episode: 315/391, score: 210.0, e: 0
# episode: 316/391, score: 210.0, e: 0
# episode: 317/391, score: 210.0, e: 0
# episode: 318/391, score: 210.0, e: 0
# episode: 319/391, score: 210.0, e: 0
# episode: 320/391, score: 210.0, e: 0
# episode: 321/391, score: 210.0, e: 0
# episode: 322/391, score: 205.0, e: 0
# episode: 323/391, score: 180.0, e: 0
# episode: 324/391, score: 210.0, e: 0
# episode: 325/391, score: 210.0, e: 0
# episode: 326/391, score: 210.0, e: 0
# episode: 327/391, score: 210.0, e: 0
# episode: 328/391, score: 210.0, e: 0
# episode: 329/391, score: 210.0, e: 0
# episode: 330/391, score: 210.0, e: 0
# episode: 331/391, score: 210.0, e: 0
# episode: 332/391, score: 210.0, e: 0
# episode: 333/391, score: 210.0, e: 0
# episode: 334/391, score: 210.0, e: 0
# episode: 335/391, score: 210.0, e: 0
# episode: 336/391, score: 210.0, e: 0
# episode: 337/391, score: 210.0, e: 0
# episode: 338/391, score: 210.0, e: 0
# episode: 339/391, score: 210.0, e: 0
# episode: 340/391, score: 210.0, e: 0
# episode: 341/391, score: 210.0, e: 0
# episode: 342/391, score: 210.0, e: 0
# episode: 343/391, score: 210.0, e: 0
# episode: 344/391, score: 210.0, e: 0
# episode: 345/391, score: 210.0, e: 0
# episode: 346/391, score: 210.0, e: 0
# episode: 347/391, score: 210.0, e: 0
# episode: 348/391, score: 210.0, e: 0
# episode: 349/391, score: 210.0, e: 0
# episode: 350/391, score: 210.0, e: 0
# episode: 351/391, score: 210.0, e: 0
# episode: 352/391, score: 152.0, e: 0
# episode: 353/391, score: 151.0, e: 0
# episode: 354/391, score: 210.0, e: 0
# episode: 355/391, score: 210.0, e: 0
# episode: 356/391, score: 210.0, e: 0
# episode: 357/391, score: 194.0, e: 0
# episode: 358/391, score: 208.0, e: 0
# episode: 359/391, score: 210.0, e: 0
# episode: 360/391, score: 210.0, e: 0
# episode: 361/391, score: 199.0, e: 0
# episode: 362/391, score: 125.0, e: 0
# episode: 363/391, score: 210.0, e: 0
# episode: 364/391, score: 210.0, e: 0
# episode: 365/391, score: 210.0, e: 0
# episode: 366/391, score: 115.0, e: 0
# episode: 367/391, score: 210.0, e: 0
# episode: 368/391, score: 210.0, e: 0
# episode: 369/391, score: 210.0, e: 0
# episode: 370/391, score: 210.0, e: 0
# episode: 371/391, score: 196.0, e: 0
# episode: 372/391, score: 210.0, e: 0
# episode: 373/391, score: 210.0, e: 0
# episode: 374/391, score: 210.0, e: 0
# episode: 375/391, score: 210.0, e: 0
# episode: 376/391, score: 194.0, e: 0
# episode: 377/391, score: 210.0, e: 0
# episode: 378/391, score: 210.0, e: 0
# episode: 379/391, score: 210.0, e: 0
# episode: 380/391, score: 210.0, e: 0
# episode: 381/391, score: 210.0, e: 0
# episode: 382/391, score: 210.0, e: 0
# episode: 383/391, score: 210.0, e: 0
# episode: 384/391, score: 166.0, e: 0
# episode: 385/391, score: 190.0, e: 0
# episode: 386/391, score: 210.0, e: 0
# episode: 387/391, score: 210.0, e: 0
# episode: 388/391, score: 197.0, e: 0
# episode: 389/391, score: 139.0, e: 0
# episode: 390/391, score: 210.0, e: 0

# %% [markdown]
# **Results**
# Here is a graph of the results. If everything was done correctly you should see the rewards over the red line.
#
# Black: This is the 100 episode rolling average
# Red: This is the "solved" line at 195
# Blue: This is the reward for each episode
# Green: This is the value of epsilon scaled by 200
# Yellow: This is where the tests started.

# %%
#Plotting
rolling_average = np.convolve(rewards, np.ones(100)/100)

plt.plot(rewards)
plt.plot(rolling_average, color='black')
plt.axhline(y=195, color='r', linestyle='-') #Solved Line
#Scale Epsilon (0.001 - 1.0) to match reward (0 - 200) range
eps_graph = [200*x for x in epsilons]
plt.plot(eps_graph, color='g', linestyle='-')
#Plot the line where TESTING begins
plt.axvline(x=TRAIN_END, color='y', linestyle='-')
plt.xlim( (0,EPISODES) )
plt.ylim( (0,220) )
plt.show()

# %% [markdown]
# **Changes**
# These are all the same changes as the DQN notebook with the exception of the update weights parameter.
# *hyper parameters*: You can alter alpha, gamma, batch size, and episode length to see what differences the algorithm returns.
# *Training End*: You can also change the line where I only check the last 5 runs before switching to testing mode (if len(rewards) > 5 and np.average(rewards[-5:]) > 195:) as that doesn't prove it was solved. The reason I did this was because I wanted to limit the amount of runs I made.
# *Update Weights*: I call 'dqn.update_target_from_model()' after every episode. You can adjust this to run at different times. I have done per step (no matter how long the episode ran) and I have seen it done every X episodes. Feel free to try different things.

# %% [markdown]
# **Conclusion**
# This is a Double Deep Q-Network implementation. There are some changes you can make here and there but it follows the paper as close as I could. If you want to dive deeper you can see that the paper has graphs that dive deeper into the inner workings of the neural network.

# %% [markdown]
# **Reference**
# Van Hasselt, H., Guez, A., & Silver, D. (2016, February). Deep Reinforcement Learning with Double Q-Learning. In AAAI (Vol. 2, p. 5)
